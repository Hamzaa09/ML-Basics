# %%
import numpy as np

# %%
np.random.seed(42)

print(np.random.randint(100,900))
# Out:
# 202

# %%
# arr = np.random.rand(3,2)
# arr = np.random.randint()

arr = np.random.randint([2, 4, 8], [[100], [200], [300]])
uniform = np.random.uniform(low=0, high=100, size=5)

uniform
# Out:
# array([52.083426  , 96.11720243, 84.45338487, 74.73201101, 53.96921324])

# %%
arr = np.array([10, 20, 30, 40])

choice = np.random.choice(arr, size=3, replace=False)
choice
# Out:
# array([40, 10, 20])
