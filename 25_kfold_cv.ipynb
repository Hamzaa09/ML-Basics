# %%
import pandas as pd 
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
iris = load_iris()

nb = GaussianNB()

score = cross_val_score(nb, iris.data, iris.target, cv=5, scoring='accuracy')

print(f"Score: {score}")
print(f"Mean Score: {score.mean()}")
print(f"Score Std: {score.std()}")
# Out:
# Score: [0.93333333 0.96666667 0.93333333 0.93333333 1.        ]
# Mean Score: 0.9533333333333334
# Score Std: 0.02666666666666666
