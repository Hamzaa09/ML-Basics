# %%
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset("titanic")

df['age'].plot.bar()
# Out:
# <Axes: >

# %%
df['age'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.bar(stacked=True, figsize=(10, 6), title='Stacked Bar Plot', xlabel='pclass', ylabel='fare', grid=True)
# Out:
# <Axes: title={'center': 'Stacked Bar Plot'}, xlabel='pclass', ylabel='fare'>
