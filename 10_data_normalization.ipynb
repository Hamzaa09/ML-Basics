# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer

# %%
df = [[1, 1, 1], [1, 1, 0], [1, 0, 0]]
normalizer = Normalizer(norm='l2')
print(normalizer.fit_transform(df))
# Out:
# [[0.57735027 0.57735027 0.57735027]
#  [0.70710678 0.70710678 0.        ]
#  [1.         0.         0.        ]]

# %%
df_2 = [[1, 1, 1], [1, 1, 0], [1, 0, 0]]
normalizer = Normalizer(norm='l1')
print(normalizer.fit_transform(df_2))
# Out:
# [[0.33333333 0.33333333 0.33333333]
#  [0.5        0.5        0.        ]
#  [1.         0.         0.        ]]

# %%
df = pd.DataFrame({"values":[1, 5, 20, 100, 500, 1000, 1500, 10000, 100000]})
df
# Out:
#    values
# 0       1
# 1       5
# 2      20
# 3     100
# 4     500
# 5    1000
# 6    1500
# 7   10000
# 8  100000

# %%
df['log_values'] = np.log(df['values'])
df
# Out:
#    values  log_values
# 0       1    0.000000
# 1       5    1.609438
# 2      20    2.995732
# 3     100    4.605170
# 4     500    6.214608
# 5    1000    6.907755
# 6    1500    7.313220
# 7   10000    9.210340
# 8  100000   11.512925

# %%
for col in df.columns:
    sns.histplot(df[col], kde=True)
    plt.show()
