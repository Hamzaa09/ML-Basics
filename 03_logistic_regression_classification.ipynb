# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression

# %%
df = sns.load_dataset('titanic')
df["sex_num"] = df["sex"].map({"male": 0, "female": 1})

df.head()
# Out:
#    survived  pclass     sex   age  ...  embark_town  alive  alone sex_num
# 0         0       3    male  22.0  ...  Southampton     no  False       0
# 1         1       1  female  38.0  ...    Cherbourg    yes  False       1
# 2         1       3  female  26.0  ...  Southampton    yes   True       1
# 3         1       1  female  35.0  ...  Southampton    yes  False       1
# 4         0       3    male  35.0  ...  Southampton     no   True       0
#
# [5 rows x 16 columns]

# %%
X = df[['pclass', 'sex_num']]
y = df['alive']

model = LogisticRegression()
model.fit(X, y)

print(model.predict([[1, 0]]))
print(model.predict([[2, 0]]))
print(model.predict([[1, 1]]))
print(model.predict([[2, 1]]))
# Out:
# ['no']
# ['no']
# ['yes']
# ['yes']
# c:\Users\hamza\miniconda3\envs\pythonMLBasics\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\hamza\miniconda3\envs\pythonMLBasics\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\hamza\miniconda3\envs\pythonMLBasics\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\hamza\miniconda3\envs\pythonMLBasics\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
